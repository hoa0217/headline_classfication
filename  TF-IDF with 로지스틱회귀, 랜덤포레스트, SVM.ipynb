# %%
import os

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
train_data = pd.read_csv( 'data_clean.csv' )
train_data = train_data[train_data['text'].notnull()]

# %%
train_data.head()
# Out:
#                                                 text sentiment
# 0  according gran company plans move production r...   neutral
# 1  technopolis plans develop stages area less squ...   neutral
# 2  international electronic industry company elco...  negative
# 3  new production plant company would increase ca...  positive
# 4  according company updated strategy years baswa...  positive

# %%
text = list(train_data['text'])
sentiments = list(train_data['sentiment'])

# %%
vectorizer = TfidfVectorizer(min_df = 0.0, analyzer="word"
                             , sublinear_tf=True, ngram_range=(1,3), max_features=10000)

# %%
X = vectorizer.fit_transform(text).toarray()
y = np.array(sentiments)

# %%
X.shape
# Out:
# (4845, 10000)

# %%
features = vectorizer.get_feature_names()

# %%
features
# Out:
# ['ab',
#  'ab publ',
#  'ab sto',
#  'abb',
#  'ability',
#  'able',
#  'able deliver',
#  'abloy',
#  'abn',
#  'abn amro',
#  'abp',
#  'abp hel',
#  'abp hel fisas',
#  'abp net',
#  'abp net profit',
#  'abroad',
#  'ac',
#  'ac cxe',
#  'ac cxe amplifier',
#  'ac drives',
#  'ac drives manufacturer',
#  'ac million',
#  'ac million million',
#  'ac million us',
#  'ac million year',
#  'ac nielsen',
#  'ac nielsen data',
#  'ac us',
#  'ac us helsinki',
#  'acacia',
#  'access',
#  'accessories',
#  'accident',
#  'accommodate',
#  'accommodate steel',
#  'accommodate steel grc',
#  'accordance',
#  'accordance agreement',
#  'accordance chapter',
#  'accordance chapter section',
#  'accordance section',
#  'according',
#  'according ac',
#  'according ac nielsen',
#  'according ceo',
#  'according ceo matti',
#  'according company',
#  'according finnish',
#  'according interim',
#  'according interim report',
#  'according notice',
#  'according olvi',
#  'according preliminary',
#  'according report',
#  'according rules',
#  'according scanfil',
#  'account',
#  'accountant',
#  'accounted',
#  'accounted net',
#  'accounted net sales',
#  'accounted percent',
#  'accounting',
#  'accounting period',
#  'accounts',
#  'accounts approximately',
#  'accounts approximately sales',
#  'acg',
#  'acg said',
#  'acg said today',
#  'achieve',
#  'achieve eur',
#  'achieved',
#  'acknowledged',
#  'acquire',
#  'acquire shares',
#  'acquired',
#  'acquired pct',
#  'acquires',
#  'acquiring',
#  'acquisition',
#  'acquisition expected',
#  'acquisition part',
#  'acquisition part ramirent',
#  'acquisition price',
#  'acquisitions',
#  'across',
#  'act',
#  'acting',
#  'action',
#  'actions',
#  'active',
#  'actively',
#  'activities',
#  'activity',
#  'actual',
#  'actual agreement',
#  'actual market',
#  'actual situation',
#  'actual situation future',
#  'actually',
#  'adac',
#  'add',
#  'added',
#  'added pct',
#  'added pct eur',
#  'adding',
#  'addition',
#  'additional',
#  'additional costs',
#  'additionally',
#  'address',
#  'adds',
#  'adjust',
#  'adjust operations',
#  'adjusted',
#  'adjustment',
#  'adjustments',
#  'administration',
#  'adp',
#  'adp news',
#  'adp news feb',
#  'adp news jan',
#  'adp news nov',
#  'adp news oct',
#  'adpnews',
#  'adpnews dec',
#  'advanced',
#  'advantage',
#  'advertising',
#  'advisory',
#  'afe',
#  'afe said',
#  'afe said today',
#  'affairs',
#  'affarsvarlden',
#  'affect',
#  'affected',
#  'affecto',
#  'affecto oyj',
#  'affecto oyj hel',
#  'affectogenimap',
#  'africa',
#  'afternoon',
#  'afx',
#  'afx kci',
#  'afx kci konecranes',
#  'afx news',
#  'afx outokumpu',
#  'ag',
#  'agency',
#  'agenda',
#  'aggregate',
#  'agm',
#  'ago',
#  'ago eur',
#  'agreed',
#  'agreed buy',
#  'agreed disclose',
#  'agreed sell',
#  'agreement',
#  'agreement acquire',
#  'agreement covers',
#  'agreements',
#  'agricultural',
#  'ahead',
#  'ahlstrom',
#  'ahlstrom com',
#  'ahlstrom corporation',
#  'ahlstrom corporation stock',
#  'ahlstrom share',
#  'aho',
#  'aim',
#  'aimed',
#  'aims',
#  'air',
#  'airbus',
#  'aircraft',
#  'airline',
#  'airlines',
#  'airport',
#  'airports',
#  'aker',
#  'aker yards',
#  'aktia',
#  'alandsbanken',
#  'aldata',
#  'aldata solution',
#  'aldata solution oyj',
#  'alexander',
#  'alexandria',
#  'alexandria va',
#  'alexandria va dec',
#  'alexandria va march',
#  'alexandria va oct',
#  'alfa',
#  'alliance',
#  'allow',
#  'allowed',
#  'allows',
#  'alma',
#  'alma media',
#  'alma media corporation',
#  'alma media shares',
#  'almost',
#  'aln',
#  'alone',
#  'along',
#  'already',
#  'already started',
#  'also',
#  'also agreed',
#  'also decided',
#  'also include',
#  'also includes',
#  'also noted',
#  'also offer',
#  'also owns',
#  'also provide',
#  'also provides',
#  'also reached',
#  'also said',
#  'also set',
#  'also signed',
#  'also six',
#  'also six year',
#  'also strengthen',
#  'also strong',
#  'also turned',
#  'also turned earnings',
#  'also used',
#  'also viewed',
#  'also viewed live',
#  'alternative',
#  'although',
#  'altia',
#  'altima',
#  'altimo',
#  'altogether',
#  'altona',
#  'aluminium',
#  'aluminum',
#  'alus',
#  'alus controlled',
#  'alus controlled nordic',
#  'always',
#  'amanda',
#  'amanda capital',
#  'amer',
#  'amer sports',
#  'amer sports corp',
#  'amer sports corporation',
#  'america',
#  'america asia',
#  'america llc',
#  'america llc sna',
#  'america said',
#  'american',
#  'american airlines',
#  'american licensing',
#  'american licensing partner',
#  'amex',
#  'among',
#  'among biggest',
#  'among others',
#  'amount',
#  'amount eur',
#  'amount eur mn',
#  'amount shares',
#  'amounted',
#  'amounted eur',
#  'amounted eur eur',
#  'amounted eur million',
#  'amounted eur mn',
#  'amounted loss',
#  'amounted loss eur',
#  'amounts',
#  'amounts eur',
#  'amplifier',
#  'analyses',
#  'analyses cement',
#  'analysis',
#  'analysis gives',
#  'analysis gives clear',
#  'analysis pharmaceutical',
#  'analysis pharmaceutical markets',
#  'analysis provided',
#  'analyst',
#  'analysts',
#  'analysts said',
#  'analytics',
#  'angeles',
#  'animal',
#  'animal fat',
#  'announce',
#  'announced',
#  'announced plans',
#  'announced today',
#  'announced today launch',
#  'announcement',
#  'annual',
#  'annual capacity',
#  'annual general',
#  'annual general meeting',
#  'annual improvement',
#  'annual net',
#  'annual net sales',
#  'annual production',
#  'annual production capacity',
#  'annual report',
#  'annual revenue',
#  'annual sales',
#  'annual savings',
#  'annual savings eur',
#  'annual turnover',
#  'annually',
#  'annum',
#  'another',
#  'answer',
#  'antenna',
#  'antibody',
#  'anticipated',
#  'anticipates',
#  'anttila',
#  'apart',
#  'apartment',
#  'apartments',
#  'apetit',
#  'apiece',
#  'appears',
#  'apple',
#  'application',
#  'applications',
#  'applications including',
#  'applied',
#  'apply',
#  'appointed',
#  'approach',
#  'appropriate',
#  'approval',
#  'approve',
#  'approved',
#  'approx',
#  'approximately',
#  'approximately employees',
#  'approximately eur',
#  'approximately eur million',
#  'approximately million',
#  'approximately people',
#  'approximately persons',
#  'april',
#  'april finnish',
#  'april june',
#  'arabia',
#  'area',
#  'area providing',
#  'area sq',
#  'area square',
#  'areas',
#  'arena',
#  'arena partners',
#  'arm',
#  'around',
#  'around eur',
#  'around million',
#  'around mln',
#  'around mln eur',
#  'around world',
#  'arranged',
#  'arrangement',
#  'arrangements',
#  'art',
#  'arts',
#  'asa',
#  'asa osl',
#  'asia',
#  'asia pacific',
#  'asian',
#  'asked',
#  'asphalt',
#  'aspo',
#  'aspo group',
#  'aspo plc',
#  'aspo plc stock',
#  'aspo systems',
#  'aspocomp',
#  'aspocomp group',
#  'aspocomp group oyj',
#  'assembly',
#  'asset',
#  'asset management',
#  'assets',
#  'assigned',
#  'assignment',
#  'associated',
#  'associates',
#  'association',
#  'atria',
#  'attached',
#  'attached shares',
#  'attacks',
#  'attempt',
#  'attention',
#  'attract',
#  'attractive',
#  'audio',
#  'audio webcast',
#  'aug',
#  'august',
#  'august finnish',
#  'august operating',
#  'august operating profit',
#  'australia',
#  'austria',
#  'austrian',
#  'authentication',
#  'authorities',
#  'authority',
#  'authorized',
#  'auto',
#  'automatically',
#  'automation',
#  'automation solution',
#  'automation solutions',
#  'automation solutions developer',
#  'automobile',
#  'automotive',
#  'autumn',
#  'available',
#  'available company',
#  'avenue',
#  'average',
#  'aviation',
#  'award',
#  'awarded',
#  'awarded contract',
#  'awarded order',
#  'awards',
#  'away',
#  'back',
#  'back strong',
#  'backup',
#  'bags',
#  'bags accessories',
#  'balance',
#  'balance sheet',
#  'balance sheet eur',
#  'balanced',
#  'ball',
#  'baltic',
#  'baltic countries',
#  'baltic pearl',
#  'baltic pearl cjsc',
#  'baltic sea',
#  'baltic states',
#  'baltics',
#  'baltimore',
#  'ban',
#  'band',
#  'bands',
#  'bangalore',
#  'bank',
#  'bank ab',
#  'bank also',
#  'bank danske',
#  'bank estonia',
#  'bank eur',
#  'bank eur bn',
#  'bank finland',
#  'bank finland plc',
#  'bank forecasts',
#  'bank group',
#  'bank hel',
#  'bank hel poh',
#  'bank hel samas',
#  'bank helsinki',
#  'bank helsinki branch',
#  'bank land',
#  'bank land net',
#  'bank land reports',
#  'bank million',
#  'bank nordea',
#  'bank plc',
#  'bank sto',
#  'bank sto nda',
#  'banked',
#  'banking',
#  'banks',
#  'banks nordea',
#  'banks nordea bank',
#  'bar',
#  'barc',
#  'barclays',
#  'bas',
#  'bas said',
#  'base',
#  'base metal',
#  'base metals',
#  'base station',
#  'base stations',
#  'based',
#  'based company',
#  'based company awarded',
#  'based company stock',
#  'based international',
#  'based international machinery',
#  'based materials',
#  'based monitoring',
#  'based monitoring technology',
#  'based norway',
#  'based service',
#  'based services',
#  'based steel',
#  'based steel maker',
#  'based strong',
#  'based subsidiary',
#  'based values',
#  'basf',
#  'basic',
#  'basic engineering',
#  'basis',
#  'basis excess',
#  'basis excess average',
#  'basketball',
#  'basketball team',
#  'basware',
#  'basware business',
#  'basware business transactions',
#  'basware connectivity',
#  'basware connectivity services',
#  'basware contract',
#  'basware contract matching',
#  'basware corporation',
#  'basware enterprise',
#  'basware enterprise purchase',
#  'basware invoice',
#  'basware invoice automation',
#  'basware invoice processing',
#  'basware kpi',
#  'basware kpi reporting',
#  'basware order',
#  'basware order matching',
#  'basware oyj',
#  'basware oyj said',
#  'batch',
#  'batch plant',
#  'bavaria',
#  'bavaria industriekapital',
#  'bavaria industriekapital ag',
#  'bavelloni',
#  'bavelloni pre',
#  'bavelloni pre processing',
#  'bay',
#  'bbh',
#  'bbh posted',
#  'bbl',
#  'bcs',
#  'bearing',
#  'became',
#  'became substantial',
#  'became substantial holder',
#  'become',
#  'becomes',
#  'becoming',
#  'bed',
#  'beef',
#  'beer',
#  'beer market',
#  'beer sales',
#  'beers',
#  'begin',
#  'beginning',
#  'behalf',
#  'behind',
#  'beijing',
#  'belgian',
#  'belgium',
#  'benchmark',
#  'benchmark year',
#  'benecol',
#  'benefits',
#  'benefon',
#  'bertrand',
#  'bertrand sciard',
#  'besides',
#  'best',
#  'best known',
#  'better',
#  'beverage',
#  'beverages',
#  'beyond',
#  'bg',
#  'bhushan',
#  'bhushan steel',
#  'bid',
#  'big',
#  'bigger',
#  'biggest',
#  'billing',
#  'billing charging',
#  'billing charging rating',
#  'billion',
#  'billion billion',
#  'billion dollars',
#  'billion end',
#  'billion euros',
#  'bim',
#  'bim building',
#  'bim building information',
#  'biodiesel',
#  'biofuels',
#  'biohit',
#  'biohit oyj',
#  'biomass',
#  'biotie',
#  'birch',
#  'birch plywood',
#  'black',
#  'bln',
#  'bln eur',
#  'block',
#  'blue',
#  'bn',
#  'bn usd',
#  'bn usd bn',
#  'bns',
#  'board',
#  'board directors',
#  'board directors also',
#  'board directors propose',
#  'board directors proposed',
#  'boards',
#  'boards pcbs',
#  'boats',
#  'body',
#  'bond',
#  'bonds',
#  'book',
#  'booked',
#  'books',
#  'boosted',
#  'bothnia',
#  'botnia',
#  'bottom',
#  'bought',
#  'boxes',
#  'bp',
#  'branch',
#  'brand',
#  'brand new',
#  'brand new market',
#  'branded',
#  'brands',
#  'brands include',
#  'brazil',
#  'brazilian',
#  'breweries',
#  'brewery',
#  'bridge',
#  'brief',
#  'bring',
#  'bringing',
#  'brings',
#  'britain',
#  'british',
#  'broad',
#  'broadband',
#  'broadband data',
#  'broadband data communication',
#  'broker',
#  'brokerage',
#  'brought',
#  'browser',
#  'budget',
#  'build',
#  'builders',
#  'building',
#  'building construction',
#  'building gross',
#  'building home',
#  'building home improvement',
#  'building information',
#  'building information modeling',
#  'building services',
#  'building services building',
#  'building system',
#  'buildings',
#  'builds',
#  'built',
#  'bulgaria',
#  'bullish',
#  'bunge',
#  'burdened',
#  'business',
#  'business area',
#  'business area providing',
#  'business areas',
#  'business development',
#  'business group',
#  'business id',
#  'business intelligence',
#  'business operations',
#  'business partners',
#  'business process',
#  'business segment',
#  'business software',
#  'business transactions',
#  'business transactions service',
#  'business unit',
#  'business units',
#  'businesses',
#  'buy',
#  'buy recommendation',
#  'buyer',
#  'buying',
#  'buyout',
#  'buyout capman',
#  'buyout capman technology',
#  'buyout mezzanine',
#  'buyout mezzanine technology',
#  'buyout minority',
#  'buys',
#  'ca',
#  'cabin',
#  'cable',
#  'cable operators',
#  'cableway',
#  'cabot',
#  'cad',
#  'cad million',
#  'cad million approximately',
#  'calcination',
#  'calcination plant',
#  'calculated',
#  'calculates',
#  'calendar',
#  'calif',
#  'calif developed',
#  'california',
#  'call',
#  'called',
#  'callers',
#  'calls',
#  'calls data',
#  'calls data traffic',
#  'calls raw',
#  'calls raw data',
#  'calls video',
#  'calls video calls',
#  'came',
#  'came eur',
#  'came eur compared',
#  'came eur eur',
#  'came second',
#  'cameco',
#  'cameco provide',
#  'camera',
#  'cameras',
#  'campaign',
#  'campaigns',
#  'canada',
#  'canada russia',
#  'canada russia ukraine',
#  'canadian',
#  'canal',
#  'canceled',
#  'cancellation',
#  'cancellation flights',
#  'candidates',
#  'cap',
#  'cap portfolio',
#  'cap portfolio index',
#  'cap segments',
#  'capabilities',
#  'capability',
#  'capable',
#  'capacities',
#  'capacity',
#  'capacity million',
#  'capacity nokia',
#  'capacity nokia flexi',
#  'capacity tonnes',
#  'capital',
#  'capital adequacy',
#  'capital alma',
#  'capital alma media',
#  'capital biotie',
#  'capital employed',
#  'capital eur',
#  'capital eur number',
#  'capital expenditure',
#  'capital fund',
#  'capital funds',
#  'capital gain',
#  'capital gain eur',
#  'capital increase',
#  'capital increase totals',
#  'capital markets',
#  'capital markets day',
#  'capital structure',
#  'capital total',
#  'capital total eur',
#  'capital votes',
#  'capital voting',
#  'capital voting rights',
#  'capitals',
#  'capman',
#  'capman buyout',
#  'capman buyout capman',
#  'capman life',
#  'capman life science',
#  'capman plc',
#  'capman real',
#  'capman real estate',
#  'capman technology',
#  'capman technology capman',
#  'capture',
#  'car',
#  'carbon',
#  'carbon dioxide',
#  'carbon dioxide emissions',
#  'carbon disclosure',
#  'card',
#  'cards',
#  'care',
#  'career',
#  'cargo',
#  'cargo handling',
#  'cargo handling offshore',
#  'cargo volume',
#  'cargo volume increased',
#  'cargo volumes',
#  'cargotec',
#  'cargotec com',
#  'cargotec corporation',
#  'cargotec corporation press',
#  'cargotec kalmar',
#  'cargotec macgregor',
#  'cargotec macgregor business',
#  'cargotec oyj',
#  'cargotec oyj hel',
#  'cargotec sales',
#  'cargotec sales totalled',
#  'cargotec share',
#  'cargotec share capital',
#  'carolina',
#  'carriage',
#  'carried',
#  'carried record',
#  'carried record million',
#  'carried transferring',
#  'carried transferring hkscan',
#  'carrier',
#  'carrier finnair',
#  'carrier finnair oyj',
#  'carrier said',
#  'carriers',
#  'carries',
#  'carrollton',
#  'carry',
#  'carry right',
#  'carry right dividend',
#  'carrying',
#  'cars',
#  'cartel',
#  'case',
#  'cash',
#  'cash flow',
#  'cash flow investments',
#  'cash flow operating',
#  'cash flow operations',
#  'cash stock',
#  'cash upon',
#  'casing',
#  'casing member',
#  'casing member provided',
#  'catalysts',
#  'catch',
#  'categories',
#  'category',
#  'catering',
#  'catering households',
#  'cause',
#  'cause daily',
#  'caused',
#  'cautious',
#  'caverion',
#  'cba',
#  'ccs',
#  'cdli',
#  'cdp',
#  'cell',
#  'cell phone',
#  'cell phone maker',
#  'cellular',
#  'cellulose',
#  'cellulose fiber',
#  'cellulose fiber business',
#  'celular',
#  'cement',
#  'cement industry',
#  'cencorp',
#  'cencorp corporation',
#  'cencorp corporation omx',
#  'cent',
#  'cent million',
#  'cent million litres',
#  'cent rise',
#  'cent shares',
#  'cent year',
#  'cent year earlier',
#  'center',
#  'center built',
#  'center located',
#  'centers',
#  'central',
#  'central eastern',
#  'central eastern europe',
#  'central eastern european',
#  'central europe',
#  'central finland',
#  'central south',
#  'central south america',
#  'central sweden',
#  'centralized',
#  'centre',
#  'centres',
#  'centres seinajoki',
#  'centres seinajoki raahe',
#  'cents',
#  'cents share',
#  'ceo',
#  'ceo company',
#  'ceo distribution',
#  'ceo distribution nasdaq',
#  'ceo eero',
#  'ceo eero mertano',
#  'ceo hannu',
#  'ceo heikki',
#  'ceo ilkka',
#  'ceo ilkka sihvo',
#  'ceo kai',
#  'ceo kai telanne',
#  'ceo kari',
#  'ceo matti',
#  'ceo matti karppinen',
#  'ceo mika',
#  'ceo pekka',
#  'ceo tel',
#  'ceramic',
#  'ceramics',
#  'cerner',
#  'certain',
#  'certainly',
#  'certification',
#  'certified',
#  'certified roundtable',
#  'certified roundtable sustainable',
#  'cessation',
#  'cet',
#  'cfo',
#  'cgcbv',
#  'cgcbv said',
#  'cgcbv said today',
#  'chain',
#  'chain operations',
#  'chain sepp',
#  'chain stockmann',
#  'chain suomen',
#  'chains',
#  'chairman',
#  'chairman board',
#  'chairman board directors',
#  'chairman board eur',
#  'chairman eur',
#  'chairman kevin',
#  'challenge',
#  'challenges',
#  'challenging',
#  'chamber',
#  'chance',
#  'chance make',
#  'change',
#  'change fair',
#  'change fair value',
#  'changed',
#  'changes',
#  'changes built',
#  'changes built models',
#  'changes market',
#  'changes market situation',
#  'changing',
#  'changing name',
#  'channel',
#  'channels',
#  'chapter',
#  'chapter section',
#  'chapter section finnish',
#  'characteristics',
#  'characteristics btt',
#  ...]

# %%
RANDOM_SEED = 42
TEST_SPLIT = 0.2

X_train, X_eval, y_train, y_eval = train_test_split(X, y, test_size=TEST_SPLIT, random_state=RANDOM_SEED)

# %%
lgs = LogisticRegression(class_weight='balanced') 
lgs.fit(X_train, y_train)
y_pred = lgs.predict(X_eval)
print("Accuracy: %f" % lgs.score(X_eval, y_eval))
print(classification_report(y_eval,y_pred))
# Out:
# Accuracy: 0.754386
#               precision    recall  f1-score   support
#
#     negative       0.65      0.59      0.62       113
#      neutral       0.79      0.86      0.83       567
#     positive       0.71      0.61      0.65       289
#
#     accuracy                           0.75       969
#    macro avg       0.72      0.69      0.70       969
# weighted avg       0.75      0.75      0.75       969

# %%
lgs = LogisticRegression(solver = 'newton-cg', multi_class = 'multinomial') 
lgs.fit(X_train, y_train)
y_pred = lgs.predict(X_eval)
print("Accuracy: %f" % lgs.score(X_eval, y_eval))
print(classification_report(y_eval,y_pred))
# Out:
# Accuracy: 0.729618
#               precision    recall  f1-score   support
#
#     negative       0.80      0.32      0.46       113
#      neutral       0.71      0.97      0.82       567
#     positive       0.78      0.43      0.55       289
#
#     accuracy                           0.73       969
#    macro avg       0.77      0.57      0.61       969
# weighted avg       0.75      0.73      0.70       969

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators = 1000) 

forest.fit( X_train, y_train )
y_pred = forest.predict(X_eval)
print("Accuracy: %f" % forest.score(X_eval, y_eval))
print(classification_report(y_eval,y_pred))

# %%
from sklearn.svm import SVC
classifier = SVM(kernel = 'linear')
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_eval)
print("Accuracy: %f" % classifier.score(X_eval, y_eval))
print(classification_report(y_eval,y_pred))
